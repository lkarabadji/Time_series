# %% [markdown]
# <a href="https://colab.research.google.com/github/lkarabadji/Time_series/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Non Seasonal Time series

# %%
kings <- scan("http://robjhyndman.com/tsdldata/misc/kings.dat",skip=3)

# %%
kings
# Out:
#  [1] 60 43 67 50 56 42 50 65 68 43 65 34 47 34 49 41 13 35 53 56 16 43 69 59 48
# [26] 59 86 55 68 51 33 49 67 77 81 67 71 81 68 70 77 56

# %%
# Convert the data into a time series object
kingstimeseries <- ts(kings)

# %%
# Plot the time series
plot(kingstimeseries, main = "Age of Death of English Kings", xlab = "Reign", ylab = "Age")
# Out:
# Plot with title “Age of Death of English Kings”

# %% [markdown]
# Describe the time series in terms of trend, seasonality, variance ..
# - No seasonality is observed
# - Non seasonal TS consists of a trend and random component;
# - you might say that the first dozen obervations look stable and see that there is a trend up with some occasional real low values. If you ignored the outliers you might say there has been a change to a new higher mean, but that is when you ignore outliers and fall prey to Simpson's paradox or simply put "local vs global" inferences.

# %%
library(TTR)
kingsSMA3 <- SMA(kings, n=3)
plot.ts(kingsSMA3)
# Out:
# plot without title

# %%
kingsSMA3 <- SMA(kings, n=8)
plot.ts(kingsSMA3)
# Out:
# plot without title

# %%
install.packages("TTR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘zoo’

# %% [markdown]
# # Seasonal Time Series

# %%
births <- scan("http://robjhyndman.com/tsdldata/data/nybirths.dat")

# %%
start_date <- c(1946, 1)
frequency <- 12

# Create the time series object
birthstimeseries <- ts(births, start = start_date, frequency = frequency)

# %%
# Plot the time series
plot(birthstimeseries, main = "Monthly Births in New York", xlab = "Year", ylab = "Number of Births")
# Out:
# Plot with title “Monthly Births in New York”

# %% [markdown]
# -  observe a clear trend going up, increasing trend over time
# - We also observe a seasonality of
#  of births per month; there is a peak every summer, and a trough every winter.
#  - we observe a constante variance
#  - this could be described using an additive model, as the seasonal fluctuations are roughly constant in size over time and do not seem to depend on the level of the time series, and the random fluctuations seem constant over time.

# %%
birthsComp <- decompose(births)

birthsComp
# Out:
# Error in decompose(births): time series has no or less than 2 periods
# Traceback:
#
# 1. decompose(births)
# 2. stop("time series has no or less than 2 periods")

# %%
plot.ts(births)
# Out:
# plot without title
